# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000 # assists with processor speed

import matplotlib.pyplot as plt
# Only works inside notebook
# %matplotlib inline 

# import preprocessing
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer

from sklearn.neighbors import KNeighborsClassifier

import QMCBT_00_quicktips as qt
import QMCBT_01_acquire as acquire
import QMCBT_02_prepare as prepare
#import QMCBT_03_explore as explore
#import QMCBT_04_evaluate as evaluate
import QMCBT_explore_evaluate as ee
import QMCBT_wrangle as w

from env import user, password, host
# allows import reload without needing to clear kernel and rerun
# reload(packagename) 
from importlib import reload

import warnings
warnings.filterwarnings("ignore")

# %%
# This code refreshes all of my helper files (w/o the need to stop the kernel) as I continuously test and update
reload(qt)
reload(acquire)
reload(prepare)
#reload(explore)
#reload(evaluate)
reload(ee)
reload(w)
# Out:
# <module 'QMCBT_wrangle' from '/Users/qmcbt/codeup-data-science/project-2_zillow/QMCBT_wrangle.py'>

# %%
# Read in DataFrame from Codeup db using defined arguments.
df = pd.read_csv('zillow_2017_sfh_merge_all.csv')

# %% [markdown]
# # INITIAL PEEK AT DATAFRAME

# %%
# list columns
df.columns
# Out:
# Index(['parcelid', 'typeconstructiontypeid', 'storytypeid',
#        'propertylandusetypeid', 'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'id.1', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %% [markdown]
# # CHECK IS_NULL

# %%
# set temporary conditions for this instance of code
with pd.option_context('display.max_rows', None):
    # print count >0 of nulls by column
    print (df.isnull().sum().sort_values(ascending=False))
# Out:
# finishedsquarefeet15            52442
# buildingclassdesc               52442
# buildingclasstypeid             52442
# finishedsquarefeet13            52442
# storytypeid                     52395
# storydesc                       52395
# basementsqft                    52395
# yardbuildingsqft26              52379
# architecturalstyletypeid        52372
# architecturalstyledesc          52372
# typeconstructiontypeid          52366
# typeconstructiondesc            52366
# fireplaceflag                   52361
# finishedsquarefeet6             52277
# decktypeid                      52053
# pooltypeid10                    51998
# poolsizesum                     51575
# pooltypeid2                     51371
# hashottuborspa                  50927
# yardbuildingsqft17              50505
# taxdelinquencyyear              50363
# taxdelinquencyflag              50363
# finishedfloor1squarefeet        48061
# finishedsquarefeet50            48061
# threequarterbathnbr             45718
# fireplacecnt                    45199
# pooltypeid7                     42433
# poolcnt                         41346
# airconditioningtypeid           38804
# airconditioningdesc             38804
# numberofstories                 37881
# garagecarcnt                    34427
# garagetotalsqft                 34427
# regionidneighborhood            33409
# buildingqualitytypeid           18701
# unitcnt                         18594
# propertyzoningdesc              18593
# heatingorsystemtypeid           18506
# heatingorsystemdesc             18506
# regionidcity                     1037
# lotsizesquarefeet                 369
# finishedsquarefeet12              247
# fullbathcnt                       137
# calculatedbathnbr                 137
# censustractandblock               123
# yearbuilt                         116
# structuretaxvaluedollarcnt         84
# calculatedfinishedsquarefeet       82
# regionidzip                        26
# taxamount                           4
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               1
# transactiondate                     0
# propertylandusedesc                 0
# propertylandusetypeid               0
# id.1                                0
# logerror                            0
# roomcnt                             0
# assessmentyear                      0
# id                                  0
# bathroomcnt                         0
# regionidcounty                      0
# rawcensustractandblock              0
# propertycountylandusecode           0
# bedroomcnt                          0
# longitude                           0
# latitude                            0
# fips                                0
# parcelid                            0
# dtype: int64

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['typeconstructiontypeid',
#  'storytypeid',
#  'heatingorsystemtypeid',
#  'buildingclasstypeid',
#  'architecturalstyletypeid',
#  'airconditioningtypeid',
#  'basementsqft',
#  'buildingqualitytypeid',
#  'calculatedbathnbr',
#  'decktypeid',
#  'finishedfloor1squarefeet',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'finishedsquarefeet13',
#  'finishedsquarefeet15',
#  'finishedsquarefeet50',
#  'finishedsquarefeet6',
#  'fireplacecnt',
#  'fullbathcnt',
#  'garagecarcnt',
#  'garagetotalsqft',
#  'hashottuborspa',
#  'lotsizesquarefeet',
#  'poolcnt',
#  'poolsizesum',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'propertyzoningdesc',
#  'regionidcity',
#  'regionidneighborhood',
#  'regionidzip',
#  'threequarterbathnbr',
#  'unitcnt',
#  'yardbuildingsqft17',
#  'yardbuildingsqft26',
#  'yearbuilt',
#  'numberofstories',
#  'fireplaceflag',
#  'structuretaxvaluedollarcnt',
#  'taxvaluedollarcnt',
#  'landtaxvaluedollarcnt',
#  'taxamount',
#  'taxdelinquencyflag',
#  'taxdelinquencyyear',
#  'censustractandblock',
#  'airconditioningdesc',
#  'architecturalstyledesc',
#  'buildingclassdesc',
#  'heatingorsystemdesc',
#  'storydesc',
#  'typeconstructiondesc']

# %%
# creating bool series True for NaN values
bool_series = pd.isnull(df["taxamount"])
 
# filtering data
# displaying data only with team = NaN
df[bool_series]
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 3598   11666665                     NaN          NaN                    261
# 8300   11647249                     NaN          NaN                    261
# 17546  11487838                     NaN          NaN                    261
# 26352  12920381                     NaN          NaN                    261
#
#        heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 3598                     2.0                  NaN                       NaN
# 8300                     2.0                  NaN                       NaN
# 17546                    7.0                  NaN                       NaN
# 26352                    7.0                  NaN                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...   id.1  logerror  \
# 3598                     NaN   272990           NaN  ...   5366 -0.043649
# 8300                     NaN  1451273           NaN  ...  12405  0.038192
# 17546                    NaN   555782           NaN  ...  26165  0.689382
# 26352                    NaN    39253           NaN  ...  39122 -0.121397
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 3598        2017-01-25                  NaN                     NaN
# 8300        2017-02-24                  NaN                     NaN
# 17546       2017-04-13                  NaN                     NaN
# 26352       2017-05-24                  NaN                     NaN
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 3598                 NaN              Central  Single Family Residential
# 8300                 NaN              Central  Single Family Residential
# 17546                NaN           Floor/Wall  Single Family Residential
# 26352                NaN           Floor/Wall  Single Family Residential
#
#        storydesc  typeconstructiondesc
# 3598         NaN                   NaN
# 8300         NaN                   NaN
# 17546        NaN                   NaN
# 26352        NaN                   NaN
#
# [4 rows x 69 columns]

# %%
# creating bool series True for NaN values
bool_series = pd.isnull(df["regionidzip"])
 
# filtering data
# displaying data only with team = NaN
df[bool_series].T
# Out:
#                                                   2794   \
# parcelid                                      167637054
# propertylandusetypeid                               261
# id                                              1596111
# bathroomcnt                                         1.0
# bedroomcnt                                            2
# calculatedbathnbr                                   1.0
# calculatedfinishedsquarefeet                      756.0
# finishedsquarefeet12                              756.0
# fips                                               6037
# fullbathcnt                                         1.0
# latitude                                       33863071
# longitude                                    -118379246
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60376207.025
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        1953.0
# structuretaxvaluedollarcnt                      20083.0
# taxvaluedollarcnt                               84683.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           64600.0
# taxamount                                       1631.15
# censustractandblock                                 NaN
# id.1                                               4183
# logerror                                      -0.217256
# transactiondate                              2017-01-19
# propertylandusedesc           Single Family Residential
#
#                                                   6576   \
# parcelid                                      167636468
# propertylandusetypeid                               261
# id                                              1805230
# bathroomcnt                                         3.0
# bedroomcnt                                            4
# calculatedbathnbr                                   3.0
# calculatedfinishedsquarefeet                     2239.0
# finishedsquarefeet12                             2239.0
# fips                                               6037
# fullbathcnt                                         3.0
# latitude                                       34424104
# longitude                                    -118468083
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379200.353
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                     291300.0
# taxvaluedollarcnt                              508400.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          217100.0
# taxamount                                       6851.73
# censustractandblock                                 NaN
# id.1                                               9795
# logerror                                       0.014507
# transactiondate                              2017-02-14
# propertylandusedesc           Single Family Residential
#
#                                                   6809   \
# parcelid                                      167636512
# propertylandusetypeid                               261
# id                                              2460645
# bathroomcnt                                         4.0
# bedroomcnt                                            5
# calculatedbathnbr                                   4.0
# calculatedfinishedsquarefeet                     2608.0
# finishedsquarefeet12                             2608.0
# fips                                               6037
# fullbathcnt                                         4.0
# latitude                                       34424104
# longitude                                    -118468083
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379200.353
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2016.0
# structuretaxvaluedollarcnt                          NaN
# taxvaluedollarcnt                               50597.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           50597.0
# taxamount                                       1376.11
# censustractandblock                                 NaN
# id.1                                              10129
# logerror                                       0.034947
# transactiondate                              2017-02-15
# propertylandusedesc           Single Family Residential
#
#                                                   8832   \
# parcelid                                      167636496
# propertylandusetypeid                               261
# id                                              2222347
# bathroomcnt                                         3.0
# bedroomcnt                                            5
# calculatedbathnbr                                   3.0
# calculatedfinishedsquarefeet                     2157.0
# finishedsquarefeet12                             2157.0
# fips                                               6037
# fullbathcnt                                         3.0
# latitude                                       34424104
# longitude                                    -118468083
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379200.353
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                          NaN
# taxvaluedollarcnt                               55091.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           55091.0
# taxamount                                       1399.21
# censustractandblock                                 NaN
# id.1                                              13209
# logerror                                       0.003109
# transactiondate                              2017-02-28
# propertylandusedesc           Single Family Residential
#
#                                                   9001   \
# parcelid                                      167686999
# propertylandusetypeid                               261
# id                                               775695
# bathroomcnt                                         0.0
# bedroomcnt                                            0
# calculatedbathnbr                                   NaN
# calculatedfinishedsquarefeet                        NaN
# finishedsquarefeet12                                NaN
# fips                                               6037
# fullbathcnt                                         NaN
# latitude                                       34424104
# longitude                                    -118468083
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379200.353
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                           NaN
# structuretaxvaluedollarcnt                          NaN
# taxvaluedollarcnt                               26405.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           26405.0
# taxamount                                        988.48
# censustractandblock                                 NaN
# id.1                                              13467
# logerror                                      -0.068632
# transactiondate                              2017-02-28
# propertylandusedesc           Single Family Residential
#
#                                                   12465  \
# parcelid                                       17051025
# propertylandusetypeid                               261
# id                                              2654492
# bathroomcnt                                         2.0
# bedroomcnt                                            3
# calculatedbathnbr                                   2.0
# calculatedfinishedsquarefeet                     1686.0
# finishedsquarefeet12                             1686.0
# fips                                               6111
# fullbathcnt                                         2.0
# latitude                                       34374072
# longitude                                    -119475416
# lotsizesquarefeet                                5813.0
# propertycountylandusecode                          1110
# rawcensustractandblock                    61110012.0611
# regionidcity                                    34543.0
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               5
# yearbuilt                                        1952.0
# structuretaxvaluedollarcnt                      57271.0
# taxvaluedollarcnt                             1075583.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                         1018312.0
# taxamount                                      16350.94
# censustractandblock                    61110012061194.0
# id.1                                              18534
# logerror                                      -0.156173
# transactiondate                              2017-03-20
# propertylandusedesc           Single Family Residential
#
#                                                   18028  \
# parcelid                                       13963237
# propertylandusetypeid                               261
# id                                              2907523
# bathroomcnt                                         2.5
# bedroomcnt                                            4
# calculatedbathnbr                                   2.5
# calculatedfinishedsquarefeet                     2734.0
# finishedsquarefeet12                             2734.0
# fips                                               6059
# fullbathcnt                                         2.0
# latitude                                       33688579
# longitude                                    -117757313
# lotsizesquarefeet                                3441.0
# propertycountylandusecode                             1
# rawcensustractandblock                     60590524.184
# regionidcity                                        NaN
# regionidcounty                                     1286
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                     503791.0
# taxvaluedollarcnt                             1176765.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          672974.0
# taxamount                                      15688.42
# censustractandblock                                 NaN
# id.1                                              26873
# logerror                                      -0.012306
# transactiondate                              2017-04-17
# propertylandusedesc           Single Family Residential
#
#                                                   20843  \
# parcelid                                       17072012
# propertylandusetypeid                               261
# id                                              1864486
# bathroomcnt                                         4.5
# bedroomcnt                                            4
# calculatedbathnbr                                   4.5
# calculatedfinishedsquarefeet                     3436.0
# finishedsquarefeet12                             3436.0
# fips                                               6111
# fullbathcnt                                         4.0
# latitude                                       34281197
# longitude                                    -119228656
# lotsizesquarefeet                                9767.0
# propertycountylandusecode                          1110
# rawcensustractandblock                     61110018.002
# regionidcity                                        NaN
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               6
# yearbuilt                                           NaN
# structuretaxvaluedollarcnt                     363000.0
# taxvaluedollarcnt                              560991.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          197991.0
# taxamount                                        5943.9
# censustractandblock                                 NaN
# id.1                                              31077
# logerror                                      -0.030303
# transactiondate                              2017-04-28
# propertylandusedesc           Single Family Residential
#
#                                                   23350  \
# parcelid                                       17188942
# propertylandusetypeid                               261
# id                                               462233
# bathroomcnt                                         3.0
# bedroomcnt                                            4
# calculatedbathnbr                                   3.0
# calculatedfinishedsquarefeet                     3008.0
# finishedsquarefeet12                             3008.0
# fips                                               6111
# fullbathcnt                                         3.0
# latitude                                       34211295
# longitude                                    -119027964
# lotsizesquarefeet                                7475.0
# propertycountylandusecode                          1111
# rawcensustractandblock                     61110056.003
# regionidcity                                        NaN
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               8
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                     271000.0
# taxvaluedollarcnt                              775000.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          504000.0
# taxamount                                       8324.54
# censustractandblock                                 NaN
# id.1                                              34722
# logerror                                      -0.107581
# transactiondate                              2017-05-10
# propertylandusedesc           Single Family Residential
#
#                                                   23914  ...  \
# parcelid                                      167639152  ...
# propertylandusetypeid                               261  ...
# id                                                74677  ...
# bathroomcnt                                         4.0  ...
# bedroomcnt                                            5  ...
# calculatedbathnbr                                   4.0  ...
# calculatedfinishedsquarefeet                     4232.0  ...
# finishedsquarefeet12                             4232.0  ...
# fips                                               6037  ...
# fullbathcnt                                         4.0  ...
# latitude                                       33981300  ...
# longitude                                    -117803849  ...
# lotsizesquarefeet                                   NaN  ...
# propertycountylandusecode                          0100  ...
# rawcensustractandblock                  60374033.244003  ...
# regionidcity                                        NaN  ...
# regionidcounty                                     3101  ...
# regionidzip                                         NaN  ...
# roomcnt                                               0  ...
# yearbuilt                                        1977.0  ...
# structuretaxvaluedollarcnt                     800000.0  ...
# taxvaluedollarcnt                             1600000.0  ...
# assessmentyear                                     2016  ...
# landtaxvaluedollarcnt                          800000.0  ...
# taxamount                                      17926.36  ...
# censustractandblock                                 NaN  ...
# id.1                                              35555  ...
# logerror                                       0.019842  ...
# transactiondate                              2017-05-12  ...
# propertylandusedesc           Single Family Residential  ...
#
#                                                   34702  \
# parcelid                                      167636088
# propertylandusetypeid                               261
# id                                              2103174
# bathroomcnt                                         6.0
# bedroomcnt                                            5
# calculatedbathnbr                                   6.0
# calculatedfinishedsquarefeet                     5113.0
# finishedsquarefeet12                             5113.0
# fips                                               6037
# fullbathcnt                                         6.0
# latitude                                       34165369
# longitude                                    -118436275
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0101
# rawcensustractandblock                   60371286.02302
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                     923901.0
# taxvaluedollarcnt                             1599898.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          675997.0
# taxamount                                      19500.74
# censustractandblock                                 NaN
# id.1                                              51288
# logerror                                       0.069202
# transactiondate                              2017-06-28
# propertylandusedesc           Single Family Residential
#
#                                                   37078  \
# parcelid                                      167636727
# propertylandusetypeid                               261
# id                                              2684284
# bathroomcnt                                         3.0
# bedroomcnt                                            4
# calculatedbathnbr                                   3.0
# calculatedfinishedsquarefeet                     2670.0
# finishedsquarefeet12                             2670.0
# fips                                               6037
# fullbathcnt                                         3.0
# latitude                                       34681736
# longitude                                    -118096714
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379005.061
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2006.0
# structuretaxvaluedollarcnt                     182200.0
# taxvaluedollarcnt                              242900.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           60700.0
# taxamount                                       3865.75
# censustractandblock                                 NaN
# id.1                                              54788
# logerror                                       0.016445
# transactiondate                              2017-07-07
# propertylandusedesc           Single Family Residential
#
#                                                   38925  \
# parcelid                                       17072013
# propertylandusetypeid                               261
# id                                               835164
# bathroomcnt                                         3.5
# bedroomcnt                                            4
# calculatedbathnbr                                   3.5
# calculatedfinishedsquarefeet                     3586.0
# finishedsquarefeet12                             3586.0
# fips                                               6111
# fullbathcnt                                         3.0
# latitude                                       34281197
# longitude                                    -119228656
# lotsizesquarefeet                               11717.0
# propertycountylandusecode                          1110
# rawcensustractandblock                     61110018.002
# regionidcity                                        NaN
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               7
# yearbuilt                                           NaN
# structuretaxvaluedollarcnt                     266000.0
# taxvaluedollarcnt                              463996.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          197996.0
# taxamount                                        4933.9
# censustractandblock                                 NaN
# id.1                                              57476
# logerror                                       -0.04123
# transactiondate                              2017-07-14
# propertylandusedesc           Single Family Residential
#
#                                                   41468  \
# parcelid                                       17188862
# propertylandusetypeid                               261
# id                                               447456
# bathroomcnt                                         0.0
# bedroomcnt                                            0
# calculatedbathnbr                                   NaN
# calculatedfinishedsquarefeet                        NaN
# finishedsquarefeet12                                NaN
# fips                                               6111
# fullbathcnt                                         NaN
# latitude                                       34211295
# longitude                                    -119027964
# lotsizesquarefeet                                5807.0
# propertycountylandusecode                          1111
# rawcensustractandblock                     61110056.003
# regionidcity                                        NaN
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                           NaN
# structuretaxvaluedollarcnt                      24000.0
# taxvaluedollarcnt                              249000.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          225000.0
# taxamount                                        2727.5
# censustractandblock                                 NaN
# id.1                                              61312
# logerror                                       0.032583
# transactiondate                              2017-07-27
# propertylandusedesc           Single Family Residential
#
#                                                   42087  \
# parcelid                                       79640490
# propertylandusetypeid                               261
# id                                              2133032
# bathroomcnt                                         2.5
# bedroomcnt                                            3
# calculatedbathnbr                                   2.5
# calculatedfinishedsquarefeet                     1688.0
# finishedsquarefeet12                             1688.0
# fips                                               6059
# fullbathcnt                                         2.0
# latitude                                       33876784
# longitude                                    -117988458
# lotsizesquarefeet                                3474.0
# propertycountylandusecode                             1
# rawcensustractandblock                  60591106.073013
# regionidcity                                        NaN
# regionidcounty                                     1286
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2002.0
# structuretaxvaluedollarcnt                     173471.0
# taxvaluedollarcnt                              314659.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          141188.0
# taxamount                                       3785.04
# censustractandblock                                 NaN
# id.1                                              62228
# logerror                                       0.551633
# transactiondate                              2017-07-28
# propertylandusedesc           Single Family Residential
#
#                                                   42309  \
# parcelid                                      167637371
# propertylandusetypeid                               261
# id                                               358149
# bathroomcnt                                         5.0
# bedroomcnt                                            4
# calculatedbathnbr                                   5.0
# calculatedfinishedsquarefeet                     4000.0
# finishedsquarefeet12                             4000.0
# fips                                               6037
# fullbathcnt                                         5.0
# latitude                                       34089958
# longitude                                    -118451987
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0101
# rawcensustractandblock                     60372621.003
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2013.0
# structuretaxvaluedollarcnt                    1664376.0
# taxvaluedollarcnt                             2597367.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          932991.0
# taxamount                                      54391.29
# censustractandblock                                 NaN
# id.1                                              62572
# logerror                                       2.069414
# transactiondate                              2017-07-31
# propertylandusedesc           Single Family Residential
#
#                                                   43346  \
# parcelid                                       17188974
# propertylandusetypeid                               261
# id                                              2534994
# bathroomcnt                                         3.5
# bedroomcnt                                            4
# calculatedbathnbr                                   3.5
# calculatedfinishedsquarefeet                     3098.0
# finishedsquarefeet12                             3098.0
# fips                                               6111
# fullbathcnt                                         3.0
# latitude                                       34207894
# longitude                                    -119020965
# lotsizesquarefeet                                6500.0
# propertycountylandusecode                          1111
# rawcensustractandblock                     61110056.003
# regionidcity                                        NaN
# regionidcounty                                     2061
# regionidzip                                         NaN
# roomcnt                                               8
# yearbuilt                                           NaN
# structuretaxvaluedollarcnt                     229000.0
# taxvaluedollarcnt                              378267.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          149267.0
# taxamount                                       4104.84
# censustractandblock                                 NaN
# id.1                                              64092
# logerror                                       0.171455
# transactiondate                              2017-08-07
# propertylandusedesc           Single Family Residential
#
#                                                   48979  \
# parcelid                                      167636193
# propertylandusetypeid                               261
# id                                               686390
# bathroomcnt                                         5.0
# bedroomcnt                                            4
# calculatedbathnbr                                   5.0
# calculatedfinishedsquarefeet                     5363.0
# finishedsquarefeet12                             5363.0
# fips                                               6037
# fullbathcnt                                         5.0
# latitude                                       34133931
# longitude                                    -118422332
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                  60371439.022007
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        1991.0
# structuretaxvaluedollarcnt                     858000.0
# taxvaluedollarcnt                             2145000.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                         1287000.0
# taxamount                                       25932.1
# censustractandblock                                 NaN
# id.1                                              72460
# logerror                                       0.531992
# transactiondate                              2017-08-31
# propertylandusedesc           Single Family Residential
#
#                                                   49222  \
# parcelid                                      167636726
# propertylandusetypeid                               261
# id                                              2669317
# bathroomcnt                                         2.0
# bedroomcnt                                            3
# calculatedbathnbr                                   2.0
# calculatedfinishedsquarefeet                     1537.0
# finishedsquarefeet12                             1537.0
# fips                                               6037
# fullbathcnt                                         2.0
# latitude                                       34688663
# longitude                                    -118108009
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0101
# rawcensustractandblock                  60379005.051003
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        1956.0
# structuretaxvaluedollarcnt                     133500.0
# taxvaluedollarcnt                              178000.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                           44500.0
# taxamount                                       2634.69
# censustractandblock                                 NaN
# id.1                                              72807
# logerror                                       0.077616
# transactiondate                              2017-08-31
# propertylandusedesc           Single Family Residential
#
#                                                   50789
# parcelid                                      167636339
# propertylandusetypeid                               261
# id                                              2863251
# bathroomcnt                                         3.0
# bedroomcnt                                            3
# calculatedbathnbr                                   3.0
# calculatedfinishedsquarefeet                     2815.0
# finishedsquarefeet12                             2815.0
# fips                                               6037
# fullbathcnt                                         3.0
# latitude                                       34443504
# longitude                                    -118495682
# lotsizesquarefeet                                   NaN
# propertycountylandusecode                          0100
# rawcensustractandblock                     60379200.132
# regionidcity                                        NaN
# regionidcounty                                     3101
# regionidzip                                         NaN
# roomcnt                                               0
# yearbuilt                                        2015.0
# structuretaxvaluedollarcnt                     129100.0
# taxvaluedollarcnt                              360577.0
# assessmentyear                                     2016
# landtaxvaluedollarcnt                          231477.0
# taxamount                                       8479.82
# censustractandblock                                 NaN
# id.1                                              75160
# logerror                                       0.008174
# transactiondate                              2017-09-08
# propertylandusedesc           Single Family Residential
#
# [30 rows x 26 columns]

# %%
# Check result of dropping all columns with more than 1,442 NULL/NaN
df.dropna(axis='columns', thresh=51_000).isnull().sum().sort_values(ascending=False)
# Out:
# regionidcity                    1037
# lotsizesquarefeet                369
# finishedsquarefeet12             247
# calculatedbathnbr                137
# fullbathcnt                      137
# censustractandblock              123
# yearbuilt                        116
# structuretaxvaluedollarcnt        84
# calculatedfinishedsquarefeet      82
# regionidzip                       26
# taxamount                          4
# landtaxvaluedollarcnt              1
# taxvaluedollarcnt                  1
# id.1                               0
# logerror                           0
# roomcnt                            0
# transactiondate                    0
# assessmentyear                     0
# parcelid                           0
# regionidcounty                     0
# propertylandusetypeid              0
# rawcensustractandblock             0
# propertycountylandusecode          0
# longitude                          0
# latitude                           0
# fips                               0
# bedroomcnt                         0
# bathroomcnt                        0
# id                                 0
# propertylandusedesc                0
# dtype: int64

# %%
# Drop all columns with more than 1,442 NULL/NaN
df = df.dropna(axis='columns', thresh=51_000)

# %%
# Check Work
df.isnull().sum().sort_values(ascending=False)
# Out:
# regionidcity                    1037
# lotsizesquarefeet                369
# finishedsquarefeet12             247
# calculatedbathnbr                137
# fullbathcnt                      137
# censustractandblock              123
# yearbuilt                        116
# structuretaxvaluedollarcnt        84
# calculatedfinishedsquarefeet      82
# regionidzip                       26
# taxamount                          4
# landtaxvaluedollarcnt              1
# taxvaluedollarcnt                  1
# id.1                               0
# logerror                           0
# roomcnt                            0
# transactiondate                    0
# assessmentyear                     0
# parcelid                           0
# regionidcounty                     0
# propertylandusetypeid              0
# rawcensustractandblock             0
# propertycountylandusecode          0
# longitude                          0
# latitude                           0
# fips                               0
# bedroomcnt                         0
# bathroomcnt                        0
# id                                 0
# propertylandusedesc                0
# dtype: int64

# %%
# Check NO LOSS of records
df.shape[0]
# Out:
# 52442

# %%
# Run custom Function to check remaining nulls and percentage of DataFrame
ee.null_stats(df)
# Out:
# COUNT OF NULL/NaN PER COLUMN:
# regionidcity                    1037
# lotsizesquarefeet                369
# finishedsquarefeet12             247
# calculatedbathnbr                137
# fullbathcnt                      137
# censustractandblock              123
# yearbuilt                        116
# structuretaxvaluedollarcnt        84
# calculatedfinishedsquarefeet      82
# regionidzip                       26
# taxamount                          4
# landtaxvaluedollarcnt              1
# taxvaluedollarcnt                  1
# id.1                               0
# logerror                           0
# roomcnt                            0
# transactiondate                    0
# assessmentyear                     0
# parcelid                           0
# regionidcounty                     0
# propertylandusetypeid              0
# rawcensustractandblock             0
# propertycountylandusecode          0
# longitude                          0
# latitude                           0
# fips                               0
# bedroomcnt                         0
# bathroomcnt                        0
# id                                 0
# propertylandusedesc                0
# dtype: int64
#
#      DataFrame Row Count: 52442
#       NULL/NaN Row Count: 1768
#
#   DataFrame Percent kept: 0.9663
# NULL/NaN Percent dropped: 0.0337

# %%
# Drop rows with NULL/NaN since it is only 3% of DataFrame 
df = df.dropna()

# %%
# Check Work
df.isnull().sum().sort_values(ascending=False)
# Out:
# parcelid                        0
# propertylandusetypeid           0
# transactiondate                 0
# logerror                        0
# id.1                            0
# censustractandblock             0
# taxamount                       0
# landtaxvaluedollarcnt           0
# assessmentyear                  0
# taxvaluedollarcnt               0
# structuretaxvaluedollarcnt      0
# yearbuilt                       0
# roomcnt                         0
# regionidzip                     0
# regionidcounty                  0
# regionidcity                    0
# rawcensustractandblock          0
# propertycountylandusecode       0
# lotsizesquarefeet               0
# longitude                       0
# latitude                        0
# fullbathcnt                     0
# fips                            0
# finishedsquarefeet12            0
# calculatedfinishedsquarefeet    0
# calculatedbathnbr               0
# bedroomcnt                      0
# bathroomcnt                     0
# id                              0
# propertylandusedesc             0
# dtype: int64

# %% [markdown]
# # CHECK WHITESPACE

# %%
ee.check_whitespace(df)
# Out:
# There were 0 Whitespace characters found.
#
#
# COUNT OF NULL/NaN PER COLUMN:
# parcelid                        0
# propertylandusetypeid           0
# id                              0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# id.1                            0
# logerror                        0
# transactiondate                 0
# propertylandusedesc             0
# dtype: int64

# %%
rslt_df = df[df.transactiondate > '2017-12-31']
rslt_df
# Out:
#        parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
# 52441  13083743                    261  2455685          2.0           3
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 52441                2.0                        1050.0                1050.0
#
#        fips  fullbathcnt  ...  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 52441  6037          2.0  ...                     77118.0           259334.0
#
#        assessmentyear landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 52441            2016              182216.0    3345.78         6.037408e+13
#
#         id.1  logerror  transactiondate        propertylandusedesc
# 52441  77613 -0.197755       2018-05-25  Single Family Residential
#
# [1 rows x 30 columns]
